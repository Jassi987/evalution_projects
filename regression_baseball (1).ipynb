# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# %%
#downloading and exploring the dataset
#shaping the data set
df=pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
# as there is no null values  we can proceed to visualization
# It is clearly visible win is the label and required output, so now we will try 
# to link various features with the label

# %%
#plotting the distplot for all the column values
plt.figure(figsize=(20,25))
plotno=1
for i in df:
    if plotno<= 17:
        
        plt.subplot(2,4,plotno)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=10)
        plotno+=1
    
    
pt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [106], in <cell line: 4>()
#       4 for i in df:
#       5     if plotno<= 17:
# ----> 7         plt.subplot(2,4,plotno)
#       8         sns.distplot(df[i])
#       9         plt.xlabel(i,fontsize=10)
#
# File /opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:1268, in subplot(*args, **kwargs)
#    1265 fig = gcf()
#    1267 # First, search for an existing subplot with a matching spec.
# -> 1268 key = SubplotSpec._from_subplot_args(fig, args)
#    1270 for ax in fig.axes:
#    1271     # if we found an axes at the position sort out if we can re-use it
#    1272     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1273         # if the user passed no kwargs, re-use
#
# ...

# %%
#there is not much of skewness,so we can proceed

# %%
plt.figure(figsize=(20,25))
plotno=1
for i in df:
    if plotno<= 17:
        
        plt.subplot(2,3,plotno)
        sns.boxplot(y=i,data=df)
        plt.xlabel(i,fontsize=10)
        plotno+=1
    
    
pt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [108], in <cell line: 3>()
#       3 for i in df:
#       4     if plotno<= 17:
# ----> 6         plt.subplot(2,3,plotno)
#       7         sns.boxplot(y=i,data=df)
#       8         plt.xlabel(i,fontsize=10)
#
# File /opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:1268, in subplot(*args, **kwargs)
#    1265 fig = gcf()
#    1267 # First, search for an existing subplot with a matching spec.
# -> 1268 key = SubplotSpec._from_subplot_args(fig, args)
#    1270 for ax in fig.axes:
#    1271     # if we found an axes at the position sort out if we can re-use it
#    1272     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1273         # if the user passed no kwargs, re-use
#
# ...

# %%
plt.figure(figsize=(20,25))
plotno=1
for i in df:
    if plotno<= 17:
        
        plt.subplot(2,4,plotno)
        sns.regplot(x=i,y ='W',data=df)
        plt.xlabel(i,fontsize=10)
        plotno+=1
    
    
pt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [111], in <cell line: 3>()
#       3 for i in df:
#       4     if plotno<= 17:
# ----> 6         plt.subplot(2,4,plotno)
#       7         sns.regplot(x=i,y ='W',data=df)
#       8         plt.xlabel(i,fontsize=10)
#
# File /opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:1268, in subplot(*args, **kwargs)
#    1265 fig = gcf()
#    1267 # First, search for an existing subplot with a matching spec.
# -> 1268 key = SubplotSpec._from_subplot_args(fig, args)
#    1270 for ax in fig.axes:
#    1271     # if we found an axes at the position sort out if we can re-use it
#    1272     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1273         # if the user passed no kwargs, re-use
#
# ...

# %%
#inference from the above plots
# 1. Run and win are linearly correlated. And outliers are present between 850 and 900
# 2. At balls is very weekly related to Wins With no outliers.
#3.Hits are also very weekly related to winning with no outliers
# 4.Hits are also very weekly related to winning with no outliers
#5.Triple has very weak negative correlations with win with no outlier and data is right-skewed
#6.The home run has a very low correlation with wins with no lot of outliers and data is right-skewed
#7. Walk is lightly correlated to win with no outlier

#8.Strikeout is not correlated to win with no outlier and the dataset is left-skewed.
#9.Stolen Bases is not correlated to win with no outlier
#10.Stolen Bases is not correlated to win with no outlier
#11.Runs Allowed is highly correlated to win with no outliers
#12.Earned Runs is highly correlated to win with no outliers

#13.Earned Run Average (ERA) is not correlated to win with no outliers and data is right-skewed.

#14.Shutouts are highly correlated to win with no outliers and data is right-skewed.
#15.Saves are lightly correlated to win with no outliers-skewed.
#16.Errors are not correlated to win, the data has outliers and data is right-skewed.

# %%
#The number of runs, home runs, doubles, Saves, Shutouts, and Walks are highly positively linearly correlated.

#Stolen Bases, Runs Allowed, Earned Runs are highly negative linearly correlated.


#The remaining features have less to no linear correlation with no of Wins

# %%
#since we are not avle to isdentify the independent variables, so we are going to count the correlation on independent variables

# %%
corr_matrix['W'].sort_values(ascending=True)
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
#we can identify the coreelation of independent variable with te other variables
#...so we can go ahead now.

# %%
#we will try to remove the skweness in data
from sklearn.preprocessing import PowerTransformer
pw=PowerTransformer()
X= pw.fit_transform(X)

# %%
#standarad scaler to standaise our data before proceeding further
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
#spliting the data 
X_train,X_test,Y_train,Y_test=train_test_split(X_scaled,Y,test_size=0.25,random_state=29)

# %%
print('best accuracy', maxAccu , maxRs)

# %%
#spliting the data 
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=7)

# %%
#model installing and training
lr=LinearRegression()
lr.fit(X_train,Y_train)
pred=lr.predict(X_train)
pred
# Out:
# array([ 78.77135312,  67.53105273,  82.52039486,  78.61463158,
#         91.4410117 ,  96.20940963,  76.81619599,  85.95769752,
#         83.41924265,  92.38099193,  80.95254181,  83.02733276,
#         88.56190939,  72.84798878,  78.84661472,  68.30072057,
#         68.34634411,  75.44045299,  68.02694873,  90.95142554,
#         70.28753855, 100.74820034])

# %%
#now we will predict the values on test dat to check the performance of my model
Y_pred=lr.predict(X_test)

# %%
#we will check r2 score for both train and test data
print('Training data',r2_score(Y_train,pred))
print('testing data',r2_score(Y_test,Y_pred))
# Out:
# Training data 0.8797695683606025
# testing data 0.7917296649079408

# %%
import sklearn.metrics as sm
print("Mean absolute error =", round(sm.mean_absolute_error(Y_test, Y_pred), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(Y_test, Y_pred), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(Y_test, Y_pred), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(Y_test, Y_pred), 2)) 
print("R2 score =", round(sm.r2_score(Y_test, Y_pred), 2))
# Out:
# Mean absolute error = 3.76
# Mean squared error = 24.23
# Median absolute error = 2.19
# Explain variance score = 0.79
# R2 score = 0.79

# %%
# the absolute error is in the expected range ,so model is going good

# %%
#cross validation is to validate the model performance
from sklearn.model_selection import cross_val_score
cr=cross_val_score(lr,X_scaled,Y)

# %%
cr.mean()
# Out:
# -1.4228754459795805
